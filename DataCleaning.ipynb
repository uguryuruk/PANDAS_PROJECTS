# %% [markdown]
# DATA CLEANING

# %%
import numpy as np
import pandas as pd

# %%
nufus=pd.read_csv("./datasets/dunyanufusu.csv")
nufus
# Out:
#      Sıralama              Ülke          Nüfüs Yıllık değişim oranı  \
# 0         1.0             China  1,415,045,928               0.39 %
# 1         2.0             India  1,354,051,854               1.11 %
# 2         3.0              U.S.    326,766,748               0.71 %
# 3         4.0         Indonesia    266,794,980               1.06 %
# 4         5.0            Brazil    210,867,954               0.75 %
# ..        ...               ...            ...                  ...
# 228     229.0      Saint Helena          4,074               0.62 %
# 229     230.0  Falkland Islands          2,922               0.41 %
# 230     231.0              Niue          1,624               0.37 %
# 231     232.0           Tokelau          1,319               1.46 %
# 232     233.0          Holy See            801               1.14 %
#
#     Yıllık değişim Kişi/km2        km2    Göçmen  Doğum oranı  Ortalama yaş  \
# ...

# %%
nufus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sıralama              232 non-null    float64
#  1   Ülke                  232 non-null    object
#  2   Nüfüs                 232 non-null    object
#  3   Yıllık değişim oranı  232 non-null    object
#  4   Yıllık değişim        232 non-null    object
#  5   Kişi/km2              232 non-null    object
#  6   km2                   232 non-null    object
#  7   Göçmen                200 non-null    object
#  8   Doğum oranı           198 non-null    float64
#  9   Ortalama yaş          200 non-null    float64
#  10  Şehirleşme oranı      225 non-null    object
#  11  Dünya nüfus oranı     232 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 22.0+ KB

# %%
nufus.isnull()
nufus.isna().sum()
nufus.isna().all()
nufus.isnull().any()
# Out:
# Sıralama                True
# Ülke                    True
# Nüfüs                   True
# Yıllık değişim oranı    True
# Yıllık değişim          True
# Kişi/km2                True
# km2                     True
# Göçmen                  True
# Doğum oranı             True
# Ortalama yaş            True
# Şehirleşme oranı        True
# Dünya nüfus oranı       True
# dtype: bool

# %%
nufus.notna().sum()
# Out:
# Sıralama                232
# Ülke                    232
# Nüfüs                   232
# Yıllık değişim oranı    232
# Yıllık değişim          232
# Kişi/km2                232
# km2                     232
# Göçmen                  200
# Doğum oranı             198
# Ortalama yaş            200
# Şehirleşme oranı        225
# Dünya nüfus oranı       232
# dtype: int64

# %%
nufus[nufus["Şehirleşme oranı"].isnull()]
nufus[nufus["Dünya nüfus oranı"].isnull()]
nufus[nufus["Ortalama yaş"].isnull()]
# Out:
#      Sıralama                      Ülke   Nüfüs Yıllık değişim oranı  \
# 27        NaN                       NaN     NaN                  NaN
# 201     202.0               Isle of Man  84,831               0.65 %
# 202     203.0                   Andorra  76,953              -0.02 %
# 203     204.0                  Dominica  74,308               0.52 %
# 204     205.0            Cayman Islands  62,348               1.28 %
# 205     206.0                   Bermuda   61,07              -0.45 %
# 206     207.0                 Greenland  56,565               0.15 %
# 207     208.0       Saint Kitts & Nevis   55,85               0.91 %
# 208     209.0            American Samoa  55,679               0.07 %
# 209     210.0  Northern Mariana Islands  55,194               0.09 %
# 210     211.0          Marshall Islands  53,167               0.08 %
# 211     212.0            Faeroe Islands  49,489               0.40 %
# 212     213.0              Sint Maarten  40,552               1.08 %
# ...

# %%
new_nufus = nufus.dropna(thresh=12)
new_nufus = nufus.dropna(thresh=9)
new_nufus = nufus.dropna(thresh=10)
new_nufus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 200
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sıralama              195 non-null    float64
#  1   Ülke                  195 non-null    object
#  2   Nüfüs                 195 non-null    object
#  3   Yıllık değişim oranı  195 non-null    object
#  4   Yıllık değişim        195 non-null    object
#  5   Kişi/km2              195 non-null    object
#  6   km2                   195 non-null    object
#  7   Göçmen                195 non-null    object
#  8   Doğum oranı           195 non-null    float64
#  9   Ortalama yaş          195 non-null    float64
#  10  Şehirleşme oranı      195 non-null    object
#  11  Dünya nüfus oranı     195 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 19.8+ KB

# %%
# drop if both columns are empty
new_nufus = nufus.dropna(subset=["Ortalama yaş", "Doğum oranı"], how="all")
new_nufus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 200
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Sıralama              200 non-null    float64
#  1   Ülke                  200 non-null    object
#  2   Nüfüs                 200 non-null    object
#  3   Yıllık değişim oranı  200 non-null    object
#  4   Yıllık değişim        200 non-null    object
#  5   Kişi/km2              200 non-null    object
#  6   km2                   200 non-null    object
#  7   Göçmen                200 non-null    object
#  8   Doğum oranı           198 non-null    float64
#  9   Ortalama yaş          200 non-null    float64
#  10  Şehirleşme oranı      197 non-null    object
#  11  Dünya nüfus oranı     200 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 20.3+ KB
